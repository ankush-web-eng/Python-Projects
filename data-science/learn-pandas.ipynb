# %%
print("my name is Ankush")
# Out:
# my name is Ankush

# %%
import pandas as pd
df = pd.read_csv("salaries_by_college_major.csv")

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# ...

# %%
df.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
clean_df = df.dropna()

# %%
clean_df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df = clean_df

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df["Undergraduate Major"]
# Out:
# 0                               Accounting
# 1                    Aerospace Engineering
# 2                              Agriculture
# 3                             Anthropology
# 4                             Architecture
# 5                              Art History
# 6                                  Biology
# 7                      Business Management
# 8                     Chemical Engineering
# 9                                Chemistry
# 10                       Civil Engineering
# 11                          Communications
# 12                    Computer Engineering
# 13                        Computer Science
# 14                            Construction
# 15                        Criminal Justice
# 16                                   Drama
# 17                               Economics
# 18                               Education
# 19                  Electrical Engineering
# 20                                 English
# 21                                    Film
# ...

# %%
df["Undergraduate Major"].max()
# Out:
# 'Spanish'

# %%
df["Starting Median Salary"].max()
# Out:
# 74300.0

# %%
df["Starting Median Salary"].idxmax()
# Out:
# 43

# %%
df["Starting Median Salary"].loc(43)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     553         try:
# --> 554             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555         except KeyError:
#
# KeyError: 43
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-235d2ccd4594> in <cell line: 1>()
# ----> 1 df["Starting Median Salary"].loc(43)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __call__(self, axis)
#     666
#     667         if axis is not None:
# --> 668             axis = self.obj._get_axis_number(axis)
#     669         new_self.axis = axis
#     670         return new_self
#
# ...

# %%
df["Starting Median Salary"][43]
# Out:
# 74300.0

# %%
df.loc(43)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     553         try:
# --> 554             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555         except KeyError:
#
# KeyError: 43
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-6cd92f9626b9> in <cell line: 1>()
# ----> 1 df.loc(43)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __call__(self, axis)
#     666
#     667         if axis is not None:
# --> 668             axis = self.obj._get_axis_number(axis)
#     669         new_self.axis = axis
#     670         return new_self
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
# ...

# %%
df.loc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df["Undergraduate Major"].loc[df["Starting Median Salary"].idxmin()]
# Out:
# 'Spanish'

# %%
clean_df['Mid-Career 90th Percentile Salary'].subtract(clean_df['Mid-Career 10th Percentile Salary'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c33e699fe636> in <cell line: 1>()
# ----> 1 clean_df['Mid-Career 90th Percentile Salary'].subtract(clean_df['Mid-Career 10th Percentile Salary'])
#
# NameError: name 'clean_df' is not defined

# %%
df['Mid-Career 90th Percentile Salary'].subtract(df['Mid-Career 10th Percentile Salary'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-59fd625f5e2f> in <cell line: 1>()
# ----> 1 df['Mid-Career 90th Percentile Salary'].subtract(df['Mid-Career 10th Percentile Salary'])
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv("salaries_by_college_major.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-0f3d2e60f326> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("salaries_by_college_major.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df = pd.read_csv("salaries_by_college_major.csv")

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
clean_df['Mid-Career 90th Percentile Salary'].subtract(clean_df['Mid-Career 10th Percentile Salary'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c33e699fe636> in <cell line: 1>()
# ----> 1 clean_df['Mid-Career 90th Percentile Salary'].subtract(clean_df['Mid-Career 10th Percentile Salary'])
#
# NameError: name 'clean_df' is not defined

# %%
df['Mid-Career 90th Percentile Salary'].subtract(df['Mid-Career 10th Percentile Salary'])
# Out:
# 0     109800.0
# 1      96700.0
# 2     113700.0
# 3     104200.0
# 4      85400.0
# 5      96200.0
# 6      98100.0
# 7     108200.0
# 8     122100.0
# 9     102700.0
# 10     84600.0
# 11    105500.0
# 12     95900.0
# 13     98000.0
# 14    114700.0
# 15     74800.0
# 16    116300.0
# 17    159400.0
# 18     72700.0
# 19     98700.0
# 20     99600.0
# 21    102100.0
# 22    147800.0
# 23     70000.0
# 24     92000.0
# 25    111000.0
# 26     76000.0
# 27     66400.0
# 28    112000.0
# 29     88500.0
# 30    115900.0
# 31     84500.0
# 32     71300.0
# 33    118800.0
# 34    106600.0
# 35    100700.0
# 36    132900.0
# 37    137800.0
# 38     99300.0
# 39    107300.0
# 40     50700.0
# 41     65300.0
# 42    132500.0
# 43     57600.0
# 44    122000.0
# 45    126800.0
# 46     95400.0
# 47     66700.0
# 48     87300.0
# 49     65400.0
# 50         NaN
# dtype: float64

# %%
df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
df.dropna()
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
new_column = df["Mid-Career 10th Percentile Salary"].subtract(["Mid-Career 90th Percentile Salary"])
df.insert(1,"spread",new_column)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-52baf0f83e46> in <cell line: 1>()
# ----> 1 new_column = df["Mid-Career 10th Percentile Salary"].subtract(["Mid-Career 90th Percentile Salary"])
#       2 df.insert(1,"spread",new_column)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/__init__.py in flex_wrapper(self, other, level, fill_value, axis)
#     186         elif isinstance(other, (np.ndarray, list, tuple)):
#     187             if len(other) != len(self):
# --> 188                 raise ValueError("Lengths must be equal")
#     189             other = self._constructor(other, self.index)
#     190             result = self._binop(other, op, level=level, fill_value=fill_value)
#
# ValueError: Lengths must be equal

# %%
new_column = df["Mid-Career 10th Percentile Salary"]-["Mid-Career 90th Percentile Salary"]
df.insert(1,"spread",new_column)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-11-df3a51b29ff2> in <cell line: 1>()
# ----> 1 new_column = df["Mid-Career 10th Percentile Salary"]-["Mid-Career 90th Percentile Salary"]
#       2 df.insert(1,"spread",new_column)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __sub__(self, other)
#     108     @unpack_zerodim_and_defer("__sub__")
#     109     def __sub__(self, other):
# --> 110         return self._arith_method(other, operator.sub)
#     111
#     112     @unpack_zerodim_and_defer("__rsub__")
#
# ...

# %%
new_column = df["Mid-Career 10th Percentile Salary"].subtract(df["Mid-Career 90th Percentile Salary"])
df.insert(1,"spread",new_column)

# %%
df.head()
# Out:
#      Undergraduate Major    spread  Starting Median Salary  \
# 0             Accounting -109800.0                 46000.0
# 1  Aerospace Engineering  -96700.0                 57700.0
# 2            Agriculture -113700.0                 42600.0
# 3           Anthropology -104200.0                 36800.0
# 4           Architecture  -85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# ...

# %%
df.drop("spread", axis=1)
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
new_column = df["Mid-Career 90th Percentile Salary"].subtract(df["Mid-Career 10th Percentile Salary"])
df.insert(1,"spread",new_column)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-a9ad2b212570> in <cell line: 2>()
#       1 new_column = df["Mid-Career 90th Percentile Salary"].subtract(df["Mid-Career 10th Percentile Salary"])
# ----> 2 df.insert(1,"spread",new_column)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4815         if not allow_duplicates and column in self.columns:
#    4816             # Should this be a different kind of error??
# -> 4817             raise ValueError(f"cannot insert {column}, already exists")
#    4818         if not isinstance(loc, int):
#    4819             raise TypeError("loc must be int")
#
# ValueError: cannot insert spread, already exists

# %%
df
# Out:
#                      Undergraduate Major    spread  Starting Median Salary  \
# 0                             Accounting -109800.0                 46000.0
# 1                  Aerospace Engineering  -96700.0                 57700.0
# 2                            Agriculture -113700.0                 42600.0
# 3                           Anthropology -104200.0                 36800.0
# 4                           Architecture  -85400.0                 41600.0
# 5                            Art History  -96200.0                 35800.0
# 6                                Biology  -98100.0                 38800.0
# 7                    Business Management -108200.0                 43000.0
# 8                   Chemical Engineering -122100.0                 63200.0
# 9                              Chemistry -102700.0                 42600.0
# 10                     Civil Engineering  -84600.0                 53900.0
# ...

# %%
df = df.drop("spread", axis=1)

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
new_column = df["Mid-Career 90th Percentile Salary"].subtract(["Mid-Career 10th Percentile Salary"])
df.insert(1,"spread",new_column)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-f9f5f1d06d0d> in <cell line: 1>()
# ----> 1 new_column = df["Mid-Career 90th Percentile Salary"].subtract(["Mid-Career 10th Percentile Salary"])
#       2 df.insert(1,"spread",new_column)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/__init__.py in flex_wrapper(self, other, level, fill_value, axis)
#     186         elif isinstance(other, (np.ndarray, list, tuple)):
#     187             if len(other) != len(self):
# --> 188                 raise ValueError("Lengths must be equal")
#     189             other = self._constructor(other, self.index)
#     190             result = self._binop(other, op, level=level, fill_value=fill_value)
#
# ValueError: Lengths must be equal

# %%
df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#                      Undergraduate Major  Starting Median Salary  \
# 0                             Accounting                 46000.0
# 1                  Aerospace Engineering                 57700.0
# 2                            Agriculture                 42600.0
# 3                           Anthropology                 36800.0
# 4                           Architecture                 41600.0
# 5                            Art History                 35800.0
# 6                                Biology                 38800.0
# 7                    Business Management                 43000.0
# 8                   Chemical Engineering                 63200.0
# 9                              Chemistry                 42600.0
# 10                     Civil Engineering                 53900.0
# 11                        Communications                 38100.0
# 12                  Computer Engineering                 61400.0
# ...

# %%
new_column = df["Mid-Career 90th Percentile Salary"].subtract(df["Mid-Career 10th Percentile Salary"])
df.insert(1,"spread",new_column)

# %%
df.head()
# Out:
#      Undergraduate Major    spread  Starting Median Salary  \
# 0             Accounting  109800.0                 46000.0
# 1  Aerospace Engineering   96700.0                 57700.0
# 2            Agriculture  113700.0                 42600.0
# 3           Anthropology  104200.0                 36800.0
# 4           Architecture   85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# ...

# %%
df
# Out:
#                      Undergraduate Major    spread  Starting Median Salary  \
# 0                             Accounting  109800.0                 46000.0
# 1                  Aerospace Engineering   96700.0                 57700.0
# 2                            Agriculture  113700.0                 42600.0
# 3                           Anthropology  104200.0                 36800.0
# 4                           Architecture   85400.0                 41600.0
# 5                            Art History   96200.0                 35800.0
# 6                                Biology   98100.0                 38800.0
# 7                    Business Management  108200.0                 43000.0
# 8                   Chemical Engineering  122100.0                 63200.0
# 9                              Chemistry  102700.0                 42600.0
# 10                     Civil Engineering   84600.0                 53900.0
# ...

# %%
array = df.sort_values("spread")

# %%
array
# Out:
#                      Undergraduate Major    spread  Starting Median Salary  \
# 40                               Nursing   50700.0                 54200.0
# 43                   Physician Assistant   57600.0                 74300.0
# 41                             Nutrition   65300.0                 39900.0
# 49                               Spanish   65400.0                 34000.0
# 27            Health Care Administration   66400.0                 38800.0
# 47                              Religion   66700.0                 34100.0
# 23                              Forestry   70000.0                 39100.0
# 32                       Interior Design   71300.0                 36100.0
# 18                             Education   72700.0                 34900.0
# 15                      Criminal Justice   74800.0                 35000.0
# 26                        Graphic Design   76000.0                 35700.0
# ...

# %%
array.head()
# Out:
#            Undergraduate Major   spread  Starting Median Salary  \
# 40                     Nursing  50700.0                 54200.0
# 43         Physician Assistant  57600.0                 74300.0
# 41                   Nutrition  65300.0                 39900.0
# 49                     Spanish  65400.0                 34000.0
# 27  Health Care Administration  66400.0                 38800.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 40                   67000.0                            47600.0
# 43                   91700.0                            66400.0
# 41                   55300.0                            33900.0
# 49                   53100.0                            31000.0
# 27                   60600.0                            34600.0
#
#     Mid-Career 90th Percentile Salary     Group
# 40                            98300.0  Business
# 43                           124000.0      STEM
# ...

# %%
df.tail()
# Out:
#    Undergraduate Major    spread  Starting Median Salary  \
# 45   Political Science  126800.0                 40800.0
# 46          Psychology   95400.0                 35900.0
# 47            Religion   66700.0                 34100.0
# 48           Sociology   87300.0                 36500.0
# 49             Spanish   65400.0                 34000.0
#
#     Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 45                   78200.0                            41200.0
# 46                   60400.0                            31600.0
# 47                   52000.0                            29700.0
# 48                   58200.0                            30700.0
# 49                   53100.0                            31000.0
#
#     Mid-Career 90th Percentile Salary Group
# 45                           168000.0  HASS
# 46                           127000.0  HASS
# 47                            96400.0  HASS
# 48                           118000.0  HASS
# ...
